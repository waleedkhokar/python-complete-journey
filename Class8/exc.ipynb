# %%
from  typing import Dict, Union, Optional

import pprint

key = Union[int,str]
Value = Union[int, str, list, tuple, set]

# import pprint # for  beautiful printout 
# display is used mostly for jupiter notebook google 
# list  
data: Dict[key, Value] = {
    "fname": "Muhhmad", 
                        "name": "eale", 
                        "education": "BSCS",
                        "abc": [1,2,5],
                        "cde": {"a":1, "b": 2}
                        }

print("Before", data)
data.clear()
# del data
print("After", data)



methods: list[str] = [m for m in dir(data) if "__" not in m]
print(methods)
# Out:
# Before {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}
# After {}
# ['clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
from  typing import Dict, Union, Optional

import pprint

key = Union[int,str]
Value = Union[int, str, list, tuple, set]

# import pprint # for  beautiful printout 
# display is used mostly for jupiter notebook google 
# list  
data: Dict[key, Value] = {
    "fname": "Muhhmad", 
                        "name": "eale", 
                        "education": "BSCS",
                        "abc": [1,2,5],
                        "cde": {"a":1, "b": 2}
                        }

print("Before", data)
# data.clear()
del data
print("After", data)



methods: list[str] = [m for m in dir(data) if "__" not in m]
print(methods)
# Out:
# Before {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      20 # data.clear()
#      21 del data
# ---> 22 print("After", data)
#      26 methods: list[str] = [m for m in dir(data) if "__" not in m]
#      27 print(methods)
#
# NameError: name 'data' is not defined

# %% [markdown]
# # POP

# %%
from  typing import Dict, Union, Optional

import pprint

key = Union[int,str]
Value = Union[int, str, list, tuple, set]

# import pprint # for  beautiful printout 
# display is used mostly for jupiter notebook google 
# list  
data: Dict[key, Value] = {
    "fname": "Muhhmad", 
                        "name": "eale", 
                        "education": "BSCS",
                        "abc": [1,2,5],
                        "cde": {"a":1, "b": 2}
                        }

print("Before", data)
# data.clear()

a: str = data.pop("education")
print(a)

print("After", data)



# methods: list[str] = [m for m in dir(data) if "__" not in m]
# print(methods)
# Out:
# Before {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}
# BSCS
# After {'fname': 'Muhhmad', 'name': 'eale', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}

# %% [markdown]
# # popitem

# %%
from  typing import Dict, Union, Optional

import pprint

key = Union[int,str]
Value = Union[int, str, list, tuple, set]

# import pprint # for  beautiful printout 
# display is used mostly for jupiter notebook google 
# list  
data: Dict[key, Value] = {
    "fname": "Muhhmad", 
                        "name": "eale", 
                        "education": "BSCS",
                        "abc": [1,2,5],
                        "cde": {"a":1, "b": 2}
                        }

print("Before", data)
# data.clear()

a: str = data.popitem()
print(a)

print("After", data)



# methods: list[str] = [m for m in dir(data) if "__" not in m]
# print(methods)
# Out:
# Before {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}
# ('cde', {'a': 1, 'b': 2})
# After {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5]}

# %% [markdown]
# #  .get

# %%
from  typing import Dict, Union, Optional

import pprint

key = Union[int,str]
Value = Union[int, str, list, tuple, set]

# import pprint # for  beautiful printout 
# display is used mostly for jupiter notebook google 
# list  
data: Dict[key, Value] = {
    "fname": "Muhhmad", 
                        "name": "eale", 
                        "education": "BSCS",
                        "abc": [1,2,5],
                        "cde": {"a":1, "b": 2}
                        }

print("Before", data)
# data.clear()

a: str = data.get("educattrion" , "NOT")
print(a)

print("After", data)



# methods: list[str] = [m for m in dir(data) if "__" not in m]
# print(methods)
# Out:
# Before {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}
# NOT
# After {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}

# %% [markdown]
# # Another Example if its possible

# %%
from  typing import Dict, Union, Optional

import pprint

key = Union[int,str]
Value = Union[int, str, list, tuple, set]

# import pprint # for  beautiful printout 
# display is used mostly for jupiter notebook google 
# list  
data: Dict[key, Value] = {
    "fname": "Muhhmad", 
                        "name": "eale", 
                        "education": "BSCS",
                        "abc": [1,2,5],
                        "cde": {"a":1, "b": 2}
                        }

print("Before", data)
# data.clear()

a: str = data.get("education" , "NOT")
print(a)

print("After", data)



# methods: list[str] = [m for m in dir(data) if "__" not in m]
# print(methods)
# Out:
# Before {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}
# BSCS
# After {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}

# %% [markdown]
# # .setDefault

# %%
from  typing import Dict, Union, Optional

import pprint

key = Union[int,str]
Value = Union[int, str, list, tuple, set]

# import pprint # for  beautiful printout 
# display is used mostly for jupiter notebook google 
# list  
data: Dict[key, Value] = {
    "fname": "Muhhmad", 
                        "name": "eale", 
                        "education": "BSCS",
                        "abc": [1,2,5],
                        "cde": {"a":1, "b": 2}
                        }

print("Before", data)
# data.clear()

a: str = data.setdefault("educatiggon" )
print(a)

print("After", data)



# methods: list[str] = [m for m in dir(data) if "__" not in m]
# print(methods)
# Out:
# Before {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}}
# None
# After {'fname': 'Muhhmad', 'name': 'eale', 'education': 'BSCS', 'abc': [1, 2, 5], 'cde': {'a': 1, 'b': 2}, 'educatiggon': None}
