# %% [markdown]
# # Logic
# * and
# * or
# * not

# %% [markdown]
# # Comparision Operator
# * ==
# * =
# * <=
# * !=

# %% [markdown]
# # Comprehensive if-else
# ``` True_block if lojic else false_block```
# * if-else
# * if-elif-else

# %% [markdown]
# # if-else-elif
# ``` if logic:
#         true_block
#      else:
#         false_block```

# %%
if True:
    print("pakistan zinda bad")
else:
    print("hello woed")
# Out:
# pakistan zinda bad

# %%
if False:
    print("pakistan zinda bad")
else:
    print("hello woed")
# Out:
# hello woed

# %%
print("pakistan zinda bad") if False else print("hello woed")
# Out:
# hello woed

# %%
print("pakistan zinda bad") if True else print("hello woed")
# Out:
# pakistan zinda bad

# %%
if True:
    print("pakistan zinda bad")
elif False:
     print(" zinda bad")
elif False:
     print("pakistan zinda")
elif False:
    print("pan zinda bad")
else:
     print("Pakistan is not zinda bad")
# Out:
# pakistan zinda bad

# %%
if False:
    print("pakistan zinda bad")
elif False:
     print(" zinda bad")
elif False:
     print("pakistan zinda")
elif False:
    print("pan zinda bad")
else:
     print("Pakistan is not zinda bad")
# Out:
# Pakistan is not zinda bad

# %% [markdown]
# # Grading Rule

# %%
from typing import Union
persentage: float = 88.90

# %%
grade: Union[int, float] = 7.8
print(grade)
# Out:
# 7.8

# %%
per : Union[int,float] = 88
grade : Union[int,float] = None

if per >= 80:
    grade = "A+"
elif per >= 60:
    grade >= "B"
elif per>= 50:
    grade >= "C"    
elif per >= 40:
    grade >= "Fail"
 
print(f"Dear Mumtaz your your persentage is {per} is now your's result:\t  {grade}")
# Out:
# Dear Mumtaz your your persentage is 88 is now your's result:	  A+

# %% [markdown]
# # print from user input

# %%
a = int(input("enter your name: \t"))
print(type(a))
print(a)
# Out:
# <class 'int'>
# 78

# %%
per : Union[int,float] = int(input("enter your marks to chek yours grade"))
grade : Union[str, None] = None
# 
#
if per >= 0:
    grade = "fail"
elif per >= 80:
    grade = "A+"
elif per >= 60:
    grade >= "B"
elif per>= 50:
    grade >= "C"    
elif per >= 40:
    grade >= "D"
else:
    grade = "    Fail"
print(f"Dear Mumtaz your your persentage is {per} is now your's result:\t  {grade}")
# Out:
# Dear Mumtaz your your persentage is 33 is now your's result:	  fail

# %% [markdown]
# # Logical Error

# %%
from typing import Union
per : Union[int,float] = int(input("enter your marks to chek yours grade"))

# error generate if we put a float data 88.99 ... slotion is add float data types in int
grade : Union[str, None] = None
 
if per >= 0 and per < 33:
    grade = "Fail"
elif per >= 33 and per < 40:
    grade = "D"
elif per >= 40 and per < 50:
    grade = "C"
elif per >= 50 and per < 60:
    grade = "B"
elif per >= 70 and per < 90:
    grade = "A"
elif per >= 90 and per <= 100:
    grade = "A+"    
print(f"Dear Mumtaz your your persentage is {per} is now your's result:\t  {grade}")
# Out:
# Dear Mumtaz your your persentage is 88 is now your's result:	  A

# %% [markdown]
# #
# Pertype

# %%
from typing import Union, Optional
PerType = Union[int, float]
persentage: list[PerType] = [50, 60, 70]


grades : list[str] = []

for per in persentage:
    grade : str =  ""
    
if per >= 0 and per < 33:
    grade = "Fail"
elif per >= 33 and per < 40:
    grade = "D"
elif per >= 40 and per < 50:
    grade = "C"
elif per >= 50 and per < 60:
    grade = "B"
elif per >= 70 and per < 90:
    grade = "A"
elif per >= 90 and per <= 100:
     grade = "A+"    
# print(f"Dear Mumtaz your your persentage is {per} is now your's result:\t  {grade}")
         
         
         
grades.append(grade)


print(persentage)
print(grade)
# Out:
# [50, 60, 70]
# A

# %%
from typing import Union 
PerType = Union[int, float]

persentage: list[PerType] = [50, 60, 70]

grades : list[str] = []

for per in persentage:
    grade : str =  ""
  
    if (per >= 0) and (per < 33):
        grade = "Fail"
    elif (per >= 33) and (per < 40):
        grade = "D"
    elif (per >= 40) and (per < 50):
        grade = "C"
    elif (per >= 50) and (per < 60):
        grade = "B"
    elif (per >= 60) and (per < 70):
        grade = "A"
    elif (per >= 70) and (per <= 100):
        grade = "A+"
       
    grades.append(grade)
print(persentage)
print(grades)
# Out:
# [50, 60, 70]
# ['B', 'A', 'A+']

# %%
from typing import Union 
PerType = Union[int, float]

persentage: list[PerType] = [50, 60, 70]

grades : list[str] = []

for per in persentage:
    grade : str =  ""
  
    if (per >= 0) and (per < 33):
        grade = "Fail"
    elif (per >= 33) and (per < 40):
        grade = "D"
    elif (per >= 40) and (per < 50):
        grade = "C"
    elif (per >= 50) and (per < 60):
        grade = "B"
    elif (per >= 60) and (per < 70):
        grade = "A"
    elif (per >= 70) and (per <= 100):
        grade = "A+"
       
    grades.append(grade)
print(persentage)
print(grades)    
# ip(persentage, grades)
# generatiive function for loop   list
list(zip(persentage, grades))
# ADD EXRTRA DATA OR COMBINEING DATA
list(zip(persentage, grades, list(range(len(persentage)))))
# Out:
# [50, 60, 70]
# ['B', 'A', 'A+']
# [(50, 'B', 0), (60, 'A', 1), (70, 'A+', 2)]

# %%
roll: list[int] = list(range(len(persentage)))
roll
# Out:
# [0, 1, 2]

# %%
data_base = list(zip(roll,persentage, grades))
data_base
# Out:
# [(0, 50, 'B'), (1, 60, 'A'), (2, 70, 'A+')]

# %%
display(data_base)
sorted(data_base, key=lambda x:x[1], reverse=True)
# Out:
# [(0, 50, 'B'), (1, 60, 'A'), (2, 70, 'A+')]
# [(2, 70, 'A+'), (1, 60, 'A'), (0, 50, 'B')]

# %%
cars: list[str] ["honda", "civic", "bmw"]
for car in cars:
    if car == "civic":
        print(car.upper())
    else:
        print(car.title())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 cars: list[str] ["honda", "civic", "bmw"]
#       2 for car in cars:
#       3     if car == "civic":
#
# TypeError: list[str] is not a generic class

# %%
cars: str = ["honda", "civic", "bmw"]
for car in cars:
    if car == "civic":
        print(car.upper())
    else:
        print(car.title())
# Out:
# Honda
# CIVIC
# Bmw

# %%
foods: list[str] = ['biryani', 'makhan', 'malai', 'tea']

for food in foods:
    if food == "makhan":
        print(food.upper())
    else:
        print(food.title())
# Out:
# Biryani
# MAKHAN
# Malai
# Tea

# %%
car = 'Audi'
car == 'audi'
# Out:
# False

# %%
car = 'Audi'
car.lower() == 'audi'
# Out:
# True

# %%
answer = 45
if answer != 25:
print("That is not corrct answwrr")
# else:
#     print("grate chpoce")
# Out:
#   Cell In[15], line 3
#     print("That is not corrct answwrr")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
answer = 45
if answer != 25:
    print("thats not right5 anser")
# Out:
# thats not right5 anser

# %%
foods: list[str] = ['biryani', 'makhan', 'malai', 'tea']
'biryani' in foods
# Out:
# True

# %%
foods: list[str] = ['biryani', 'makhan', 'malai', 'tea']
'wak' in foods
# Out:
# False

# %%
banned_user: list[str] = ['andrew', 'angela', 'glory']
user: str = ',arie'

print(user not in banned_user )
if user not in banned_user:
    print(f"(user.title(), you can poset refuge if u want")
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'pythooon (Python 3.12.0)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
age = 17
if age >= 18:
    print("You are old to enough to vote!") print("Have you register")
elif:
      print('sorry, you are too young')
else:
     print('sorry, you are too young for voting')
# Out:
#   Cell In[2], line 3
#     print("You are old to enough to vote!") print("Have you register")
#                                             ^
# SyntaxError: invalid syntax

# %%
age = 17
if age >= 18:
    print("You are old to enough to vote!") , print ("Have you register")
    print('sorry, you are too young')
else:
     print('sorry, you are too young for voting')     print("pLESSE rejister")
# Out:
# sorry, you are too young for voting
# pLESSE rejister

# %%
age = 12
if age < 4:
    print("yout cast is 0$")
elif age < 18: 
    print("yourt adimissiojn cast in 0$")
else:
    print('yout is 00$')
# Out:
# yourt adimissiojn cast in 0$

# %%
topping : list[str] = ['mushroom', 'cheese', 'butter', 'ketchup']

if 'mushroom' in topping:
    print("adding mushroom")
if 'cheese ' in topping:
    print('adding cheese')
if 'bbbbrt' in topping:
    print('adding ')
print("\n FInished yor pizza")

# %%
#  #Start with users that need to be verified,
# # and an empty list to hold confirmed users.
# unconfirmed_users = ['alice', 'brian', 'candace']
# confirmed_users = []
# # Verify each user until there are no more unconfirmed users.
# # Move each verified user into the list of confirmed users.
# while unconfirmed_users:
# current_user = unconfirmed_users.pop()
#  print(f"Verifying user: {current_user.title()}")
# confirmed_users.append(current_user)
# # Display all confirmed users.
# print("\nThe following users have been confirmed:")
# for confirmed_user in confirmed_users:
#  print(confirmed_user.title())

# %%
requested_toppings = []
if requested_toppings:
    for requested_topping in requested_toppings:
        print(f"Adding {requested_topping}.")
    print("\nFinished making your pizza!")
else:
 print("Are you sure you want a plain pizza?")
# Out:
# Are you sure you want a plain pizza?

# %%
available_toppings = ['mushrooms', 'olives', 'green peppers','pepperoni', 'pineapple', 'extra cheese']
requested_toppings = ['mushrooms', 'french fries', 'extra cheese']
for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
         print(f"Adding {requested_topping}.")
    else:
     print(f"Sorry, we don't have {requested_topping}.")
print("\nFinished making your pizza!")
# Out:
# Adding mushrooms.
# Sorry, we don't have french fries.
# Adding extra cheese.
#
# Finished making your pizza!

# %% [markdown]
# # IF not avaliable

# %%
available_toppings = ['mushrooms', 'olives', 'green peppers','pepperoni', 'pineapple', 'extra cheese']
requested_toppings = ['mushroooojms', 'extra cheese']
for requested_topping in requested_toppings:
    if requested_topping in available_toppings:
     print(f"Adding {requested_topping}.")
    else:
     print(f"Sorry, we don't have {requested_topping}.")
print("\nFinisghhggvghvhed making your pizza!")
# Out:
# Sorry, we don't have mushroooojms.
# Adding extra cheese.
#
# Finisghhggvghvhed making your pizza!

# %% [markdown]
# # .Split is used for taking inpput form user more

# %%
input("enter you error ',' ty uyio ").split(",")
# Out:
# ['wal', ' jwd', 'kk']

# %%
user: str = input("Enter your id: \t")
password : str = input("enter your passwerod: \t")

if user == "admin" and password == "admin":
    print("chek email for otp")
otp: str= input("enter your OTP password")
if otp == '12345':
    print("Welcom IN JUHANAM")
else:
    print("Invalid User / Passwerord")
# Out:
# chek email for otp
# Welcom IN JUHANAM
